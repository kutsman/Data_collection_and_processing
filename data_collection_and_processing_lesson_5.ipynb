# %%
# !apt install mongodb > log
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# !service mongodb start
# Out:
#  * Starting database mongodb
#    ...done.

# %%
# !mongo
# Out:
# MongoDB shell version v3.6.8
# connecting to: mongodb://127.0.0.1:27017
# Implicit session: session { "id" : UUID("ec855994-4fab-46c1-a8f0-af0841b7a7d1") }
# MongoDB server version: 3.6.8
# Welcome to the MongoDB shell.
# For interactive help, type "help".
# For more comprehensive documentation, see
# 	http://docs.mongodb.org/
# Questions? Try the support group
# 	http://groups.google.com/group/mongodb-user
# Server has startup warnings:
# 2023-03-12T12:00:14.952+0000 I CONTROL  [initandlisten]
# 2023-03-12T12:00:14.952+0000 I CONTROL  [initandlisten] ** WARNING: Access control is not enabled for the database.
# 2023-03-12T12:00:14.952+0000 I CONTROL  [initandlisten] **          Read and write access to data and configuration is unrestricted.
# 2023-03-12T12:00:14.952+0000 I CONTROL  [initandlisten]
# > 2023-03-12T12:00:50.191+0000 I CONTROL  [main] shutting down with code:0

# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install scrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.9/272.9 KB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 37.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.9/257.9 KB 19.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 76.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 KB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 KB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 KB 3.9 MB/s eta 0:00:00
# ...

# %%
# !scrapy startproject parser_trend
# Out:
# New Scrapy project 'parser_trend', using template directory '/usr/local/lib/python3.9/dist-packages/scrapy/templates/project', created in:
#     /content/parser_trend
#
# You can start your first spider with:
#     cd parser_trend
#     scrapy genspider example example.com

# %% [markdown]
# # Новый раздел

# %%
cd parser_trend
# Out:
# /content/parser_trend

# %%
# !scrapy genspider lenta_ru lenta.ru
# Out:
# Created spider 'lenta_ru' using template 'basic' in module:
#   parser_trend.spiders.lenta_ru

# %%
from pymongo import MongoClient

# %%
mongo_db = MongoClient()

# %%
mongo_db
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = mongo_db['news_db']

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'news_db')

# %%
list(mongo_db.list_database_names())
# Out:
# ['admin', 'config', 'local']

# %%
# !scrapy crawl lenta_ru
# Out:
# 2023-03-12 12:41:21 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: parser_trend)
# 2023-03-12 12:41:21 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.9.16 (main, Dec  7 2022, 01:11:51) - [GCC 9.4.0], pyOpenSSL 23.0.0 (OpenSSL 3.0.8 7 Feb 2023), cryptography 39.0.2, Platform Linux-5.10.147+-x86_64-with-glibc2.31
# 2023-03-12 12:41:21 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'parser_trend',
#  'DOWNLOAD_DELAY': 1,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'parser_trend.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['parser_trend.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'}
# ...

# %%
db['lenta_ru']
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'news_db'), 'lenta_ru')

# %%
collection = db['lenta_ru']

# %%
collection.delete_many({})

# %%
from pprint import pprint

# %%
for i in collection.find(): # проверяем вывод добавленной вакансии
  pprint(i)
# Out:
# {'_id': ObjectId('640dc873a5e9c464960d8cc8'),
#  'date': ' 12 марта 2023',
#  'link': 'https://lenta.ru/news/2023/03/12/donetsk220/',
#  'name': 'Российские войска уничтожили более 220 солдат ВСУ на донецком '
#          'направлении',
#  'time': '15:09'}
# {'_id': ObjectId('640dc875a5e9c464960d8cc9'),
#  'date': ' 12 марта 2023',
#  'link': 'https://lenta.ru/news/2023/03/12/mol_protest/',
#  'name': 'В Кишиневе произошли столкновения полиции с протестующей оппозицией',
#  'time': '15:12'}
# {'_id': ObjectId('640dc876a5e9c464960d8cca'),
#  'date': ' 12 марта 2023',
#  'link': 'https://lenta.ru/news/2023/03/12/gansandity/',
#  'name': 'Россиянина ранили во время стрельбы на городской площади',
#  'time': '15:15'}
# {'_id': ObjectId('640dc877a5e9c464960d8ccb'),
#  'date': ' 12 марта 2023',
#  'link': 'https://lenta.ru/news/2023/03/12/berwyn/',
#  'name': 'Из британских тюрем уволили 31 сотрудницу за отношения с '
#          'заключенными',
#  'time': '15:16'}
# ...

# %%
import pandas as pd
df = pd.DataFrame(list(collection.find()))
df
# Out:
#                          _id  \
# 0   640dc873a5e9c464960d8cc8
# 1   640dc875a5e9c464960d8cc9
# 2   640dc876a5e9c464960d8cca
# 3   640dc877a5e9c464960d8ccb
# 4   640dc879a5e9c464960d8ccc
# 5   640dc87aa5e9c464960d8ccd
# 6   640dc87ca5e9c464960d8cce
# 7   640dc87da5e9c464960d8ccf
# 8   640dc87ea5e9c464960d8cd0
# 9   640dc87fa5e9c464960d8cd1
# 10  640dc882a5e9c464960d8cd2
# 11  640dc884a5e9c464960d8cd3
# 12  640dc885a5e9c464960d8cd4
# 13  640dc886a5e9c464960d8cd5
# 14  640dc887a5e9c464960d8cd6
# 15  640dc889a5e9c464960d8cd7
# 16  640dc88aa5e9c464960d8cd8
# 17  640dc88ba5e9c464960d8cd9
# 18  640dc88ca5e9c464960d8cda
# 19  640dc88da5e9c464960d8cdb
# 20  640dc88fa5e9c464960d8cdc
# 21  640dc890a5e9c464960d8cdd
# 22  640dc890a5e9c464960d8cde
# 23  640dc892a5e9c464960d8cdf
# 24  640dc893a5e9c464960d8ce0
# 25  640dc894a5e9c464960d8ce1
# 26  640dc897a5e9c464960d8ce2
# 27  640dc898a5e9c464960d8ce3
# 28  640dc899a5e9c464960d8ce4
# 29  640dc89ba5e9c464960d8ce5
# 30  640dc89ca5e9c464960d8ce6
# ...
